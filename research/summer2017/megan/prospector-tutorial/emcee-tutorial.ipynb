# %% [markdown]
# # Fitting a Model to Data

# %%
import numpy as np
import scipy.optimize as op
import emcee
import corner
import matplotlib.pyplot as pl
# %matplotlib inline

# %%
# Step 1: write likelihood function (the probability of a dataset given the model parameters)


# Choose the "true" parameters.
m_true = -0.9594
b_true = 4.294
f_true = 0.534

# Generate some synthetic data from the model.
N = 100
x = np.sort(15*np.random.rand(N))
yerr = 0.1+0.5*np.random.rand(N)
y = m_true*x+b_true
y += np.abs(f_true*y) * np.random.randn(N)
y += yerr * np.random.randn(N)

# %%
# Linear least squares solution

A = np.vstack((np.ones_like(x), x)).T
C = np.diag(yerr * yerr)
cov = np.linalg.inv(np.dot(A.T, np.linalg.solve(C, A)))
b_ls, m_ls = np.dot(cov, np.dot(A.T, np.linalg.solve(C, y)))

# %%
# Likelihood (Gaussian) Function

def lnlike(theta, x, y, yerr):
    m, b, lnf = theta
    model = m * x + b
    inv_sigma2 = 1.0/(yerr**2 + model**2*np.exp(2*lnf))
    return -0.5*(np.sum((y-model)**2*inv_sigma2 - np.log(inv_sigma2)))

# %%
# Find numerical optimum of this likelihood function

nll = lambda *args: -lnlike(*args)
result = op.minimize(nll, [m_true, b_true, np.log(f_true)], args=(x, y, yerr))
m_ml, b_ml, lnf_ml = result["x"]

# %%
# Log prior (up to a constant)

def lnprior(theta):
    m, b, lnf = theta
    if -5.0 < m < 0.5 and 0.0 < b < 10.0 and -10.0 < lnf < 1.0:
        return 0.0
    return -np.inf

# %%
# Full log-probability function

def lnprob(theta, x, y, yerr):
    lp = lnprior(theta)
    if not np.isfinite(lp):
        return -np.inf
    return lp + lnlike(theta, x, y, yerr)

# %%
# Sampling the Distrubution


# Start with initializing the walkers
ndim, nwalkers = 3, 100
pos = [result["x"] + 1e-4*np.random.randn(ndim) for i in range(nwalkers)]

# %%
sampler = emcee.EnsembleSampler(nwalkers, ndim, lnprob, args=(x, y, yerr))

# %%
# Run MCMC for 500 steps
sampler.run_mcmc(pos, 500)
# Out:
# (array([[-1.03630786,  4.57773431, -0.69518916],
#         [-0.982873  ,  4.38193059, -0.60268915],
#         [-0.94287152,  4.34391413, -0.65720057],
#         [-0.97928162,  4.23384979, -0.63216964],
#         [-0.95648441,  4.20615831, -0.5160289 ],
#         [-1.03970494,  4.65520766, -0.74285939],
#         [-0.98130838,  4.40299538, -0.74814701],
#         [-0.94683851,  4.30464919, -0.47775846],
#         [-1.06027384,  4.689759  , -0.60040209],
#         [-0.97970733,  4.28458321, -0.51691471],
#         [-0.98003893,  4.51909903, -0.7013782 ],
#         [-1.03551886,  4.6484067 , -0.68444876],
#         [-1.00725425,  4.70214868, -0.68439788],
#         [-0.95295323,  4.16024286, -0.58609374],
#         [-1.05764003,  4.78791277, -0.7180993 ],
#         [-0.91626447,  4.08687854, -0.50688988],
#         [-1.00192521,  4.48497483, -0.66015719],
#         [-0.94530652,  4.16783039, -0.42037491],
#         [-0.8941301 ,  4.07716769, -0.46071605],
#         [-1.09205345,  4.91724652, -0.68853914],
#         [-1.00144027,  4.43734801, -0.68355833],
#         [-1.01383401,  4.64307648, -0.62342574],
#         [-0.99959293,  4.51596407, -0.71733937],
#         [-1.0153631 ,  4.45116797, -0.54934939],
#         [-1.03035757,  4.54312267, -0.74909341],
#         [-1.03975628,  4.65909743, -0.72523879],
#         [-0.92133037,  4.26142107, -0.51065955],
#         [-0.84912976,  3.82277813, -0.39367205],
#         [-0.97831168,  4.30621129, -0.66207715],
#         [-0.98929123,  4.41252266, -0.60362567],
#         [-0.96661463,  4.28353358, -0.57304355],
#         [-1.03941814,  4.57149302, -0.60703181],
#         [-0.98501086,  4.36743991, -0.66843162],
#         [-1.05276642,  4.65395603, -0.6171649 ],
#         [-0.98348288,  4.38746507, -0.58849852],
#         [-1.01857395,  4.59113004, -0.57104119],
#         [-1.12341249,  5.09385311, -0.68869499],
#         [-1.02712797,  4.66640195, -0.64271112],
#         [-1.07029986,  4.94820637, -0.81415073],
#         [-1.12886334,  4.97381824, -0.72246612],
#         [-1.03884549,  4.79988277, -0.74019169],
#         [-1.08255483,  4.74168853, -0.6303581 ],
#         [-0.9849112 ,  4.28610977, -0.5023911 ],
#         [-0.96217311,  4.15024035, -0.63388475]]),
#  array([ -95.97985926,  -95.49385263,  -98.12498022,  -96.82827216,
#          -96.21121529,  -96.38546811,  -96.90961796,  -96.92879739,
#          -97.06540746,  -96.68275784,  -97.912571  ,  -96.01962474,
#          -98.63532776,  -96.10926036,  -96.7959211 ,  -96.25331644,
#          -95.59510436,  -97.65553504,  -97.5879427 ,  -97.51878576,
#          -95.62708616,  -96.60734165,  -96.36580343,  -97.06268919,
#          -96.11595221, -105.42073794,  -96.49290948,  -95.88143209,
#          -96.93687997,  -98.38305355,  -96.29895328,  -96.1253544 ,
#          -96.39676559,  -96.94354128,  -95.63381789,  -96.32234964,
#          -96.47009494,  -96.3937862 ,  -97.47227677,  -96.28350356,
#          -96.67170521,  -97.291023  ,  -95.98768587,  -95.85627521,
#          -95.7169676 ,  -97.79416879,  -96.46184632,  -97.23414483,
#          -95.59576121,  -97.56636431,  -98.77115831,  -97.39263547,
#          -96.20797032,  -97.08519385,  -96.41763018,  -97.55488627,
#          -96.42080602,  -97.85652966,  -96.74657203,  -98.31297593,
#          -96.04871533,  -97.49121044,  -96.6344019 ,  -97.09018637,
#          -96.24073976,  -95.86987944,  -96.6429061 ,  -96.62387708,
#          -96.16800728,  -95.60754774,  -96.07902296,  -98.01987485,
#          -96.26760083,  -96.39764152,  -95.7701546 ,  -98.75109286,
#          -97.35164057,  -95.62594901,  -97.10378628,  -96.76679727,
#          -96.3626581 ,  -96.2384507 ,  -97.93718613,  -98.51852921,
#          -95.70690001,  -95.52520445,  -95.59010979,  -96.49756329,
#          -95.5773379 ,  -96.6392276 ,  -95.5632784 ,  -96.38991331,
#          -98.942994  ,  -96.3112719 ,  -99.83988301,  -98.86309023,
#          -98.17940314,  -97.77781114,  -97.32553102,  -97.24008887]),
#          2124494432, 1863074415, 1829258960, 2341393591, 2382478442,
#          2322479748, 4030323226, 1930930493, 1557885021, 3185162434,
#          1483883191,  926084138, 3914521990, 1167876104, 3424321451,
#          1758746556, 1868709057, 2536307154, 3037314845, 2872363835,
#          3432915754, 1219077911, 1666391840,  963587792, 1102395776,
#          1830748819, 3239809299, 3483670926, 1040838379, 2156079090,
#          4060105530, 2702819866, 3759437018, 1458540283, 1567889607,
#          3391616126,  460005607, 4104085834, 3407400509, 2756346407,
#           530461501, 2630406073, 1653457540, 3914008626, 1012044222,
#          3586501353,  556033801, 3416721361,  383295182, 1779473702,
#          3054387552, 1661886522, 2861346935, 1890071844, 1906761572,
#          2632903115, 3153613571, 3176318331, 4066907784, 4109684747,
#          2551910273, 2665554385,  556999754,  469905499, 1577758940,
#          2680620918, 3976775390, 3428535966, 3451469206, 2000403681,
#           266304826,   80816717, 4188921239, 4156382783, 1558866957,
#          3477133001,  148340829, 4152219788, 2692203864, 1147037592,
#          1628509653, 1887233743,  160987534, 3731041392, 1120130310,
#           470344420, 3942374165, 2192793416, 2227634893,  988131040,
#          3035787970, 3976759757, 1836633314,  999082663, 2688679018,
#          2018463832, 2644825078, 2522243447,  461523216, 2584248137,
#          3572370213, 2611904101,  186048744, 2108931026,  468788720,
#          3466776138, 2552994051,  712123833, 1478737040, 3961675944,
#          1232836959, 3942610871,  248515745, 4226041662, 3075509608,
#          1858388171,  902900660, 2050780800,  681641374,   99405538,
#           177562464, 2921115365, 3890761642, 3335820689,  948458403,
#          3393402040, 2777895843, 1779388035,  657445986, 3246942742,
#          3862439443, 2141254002, 2260053365, 2608163563,  570094003,
#          3112400595, 1403697552, 1646637559, 2500882109, 2222346212,
#          3780101267, 4101107776, 4054999941, 3825609656,  259636743,
#          1219064633, 2587367348, 3124413651, 3899315254, 1450727987,
#           734474943, 1721177997, 1671320052, 3221359347, 2041660149,
#           340887871, 2045884204,   57652999, 2970289360], dtype=uint32), 80, 0, 0.0))

# %%
samples = sampler.chain[:, 50:, :].reshape((-1, ndim))

# %%
# Results

#error because corner is not installed
fig = corner.corner(samples, labels=["$m$", "$b$", "$\ln\,f$"],
                      truths=[m_true, b_true, np.log(f_true)])
fig.savefig("triangle.png")

# %%
pl.figure(figsize=(10,10))
xl = np.array([0, 15])
for m, b, lnf in samples[np.random.randint(len(samples), size=100)]:
    pl.plot(xl, m*xl+b, color="k", alpha=0.1)
pl.plot(xl, m_true*xl+b_true, color="r", lw=2, alpha=0.8)
pl.errorbar(x, y, yerr=yerr, fmt=".k")
print(m)
print(b)
# Out:
# -0.981193056331
# 4.49476048401

# %%
samples[:, 2] = np.exp(samples[:, 2])
m_mcmc, b_mcmc, f_mcmc = map(lambda v: (v[1], v[2]-v[1], v[1]-v[0]),
                             zip(*np.percentile(samples, [16, 50, 84],
                                                axis=0)))
