# %% [markdown]
# # Ghadeer's Summer 2017 NoteBook!

# %% [markdown]
# # Monday: 22nd of May

# %%
# the below code will help you import and appreviate at the same time
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
# the below code will help create our intial graph base
n = 30
x = np.linspace(0, 20, n)
slope = 0.2
intercept = 0
ytrue = slope * x + intercept

# %%
ynoise = ytrue + np.random.normal(scale = 0.05 * ytrue, size = n)

# %%
# the below code is for fitting
plt.figure()
plt.scatter(x, ynoise)
coefficients = np.polyfit(x, ynoise, 1)
print(coefficients)

plt.plot(x, x*coefficients[0] + coefficients[1], 'r')
# Out:
# [ 0.19674185  0.02308899]

# %% [markdown]
# # Tuesday: 23rdof May

# %%
# The Responsible Conduct of Research is finally done!
# I have organized all the toturials that I need to go through one by one
# I started reading Stellar mass -- halo mass relation and star formation efficiency in high-mass halos
# have many many questions for Dr.Moustakas!

# %% [markdown]
# # Wednesday: 24th of May

# %%
# I finished till now the first 5 sections of programming with python and I have recorded aal my notes
# on my tutorial notebook.
# I attended 30 min of Dr.Moustakas targeting discussions and it was very iteresting. 
# I got to know a bit more about DESI project
# The whole sky is a 41,253 squared degrees and DESI will be surveying 14,000 squared degrees of the sky. why?!

# %% [markdown]
# # Thrusday: 25th of May

# %%
# trying to work out the Halo Mass - BCG Mass graph

# %%
seed = 12
rand = np.random.RandomState(seed)
print(rand.uniform(size=3))
print(rand.uniform(size=3))
rand?
# Out:
# [ 0.15416284  0.7400497   0.26331502]
# [ 0.53373939  0.01457496  0.91874701]

# %%
import random
import numpy as np
import matplotlib.pyplot as plt 
from random import randint
# %matplotlib inline


seed = 123
rand  = np.random.RandomState(seed)
log10Gas = rand.uniform(size=100)

n = 100
#log10Gas = f * totalLog10Halo


epsilon = 0.02
bcgMass = epsilon * log10Gas

log10Halo = np.linspace(12, 14, n)

leftGas = log10Gas - bcgMass

totalLog10Halo = leftGas + log10Halo


plt.plot(totalLog10Halo, bcgMass, 'ro')


coefficients = np.polyfit(totalLog10Halo, bcgMass, 1)


plt.plot(totalLog10Halo, totalLog10Halo*coefficients[0] + coefficients[1], 'b')

# %%
import random
import numpy as np
import matplotlib.pyplot as plt 
from random import randint
# %matplotlib inline

# %%
seed = 123
rand  = np.random.RandomState(seed)
#log10Halo = rand.uniform(13, 15, 1)

#log10Halo1 = np.ones(50)*log10Halo


n = 50
log10Halo1 = np.linspace(13, 15, n)

epsilon = np.linspace(0.01, 0.5, n)

fraction = np.linspace(0.1, 0.5, n)



totalLog10gas = fraction * log10Halo1

bcg = epsilon * totalLog10gas

#leftHalo = log10Halo1 - totalLog10gas

# %%
plt.plot(log10Halo1, bcg, 'ro')


coefficients = np.polyfit(log10Halo1, bcg, 1)


plt.plot(log10Halo1, log10Halo1*coefficients[0] + coefficients[1], 'b')

# %% [markdown]
# # Sunday: 28th of May

# %% [markdown]
# watched a couble of videos to understand what is the difference btw Bayesian vs Frequentist and Bayes Theorem
# started wathcing: Astro Hack Week 2016: Frequentist and Bayesian Statistics with David Hogg
# started section 5 of programming with Python Toturial

# %% [markdown]
# # Monday: 29th of May

# %%
# working again on the Kravtsov A vs Gonzalez A graph

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Krovstav paper table 2 columns 7 and 9

M500_K = np.array([15.6, 10.3, 7, 5.34, 2.35, 1.86, 1.34, 0.46, 0.47])*1e14
MBCG_K = np.array([3.12, 4.14, 3.06, 1.47, 0.79, 1.26, 1.09, 0.91, 1.38])*1e12

# %%
# Gonzalez paper table 2 columns 4(where we will take the luminosity and multiply it by Υ*=2.65) and 7

M500_G = np.array([2.35, 5.37, 0.99, 3.6, 3.73, 1.03, 0.99, 3.37, 2.36, 2.51, 2.47, 1.51])*1e14
LBCG_ICL_G = np.array([0.84, 0.87, 0.33, 0.57, 0.85, 0.60, 0.86, 0.93, 0.71, 0.81, 0.7, 0.57])*2.65*1e12

# %%
fig, ax = plt.subplots(figsize=(10,5))

ax.plot(M500_K, MBCG_K,'ro', label="Kravtsov+  14")
ax.plot(M500_G, LBCG_ICL_G,'bs', label="Gonzalez+  13")
ax.legend(loc='lower right')

ax.set_xscale('log')
ax.set_yscale('log')

ax.set_xlabel('$M_{500} (M_{\odot})$')
ax.set_ylabel('$M_{*, BCG} (M_{\odot})$', fontsize = 12)

#ax.set_xlabel(r'$\log_{10}\ (M_{halo} / M_{\odot})$')
#ax.set_ylabel(r'$\log_{10}\ (M_{*} / M_{\odot})$')

ax.set_xlim(2e13, 2e15)
ax.set_ylim(5e10, 2e13)
# Out:
# (50000000000.0, 20000000000000.0)

# %% [markdown]
# # Tuesday: 30th of May

# %% [markdown]
# * We learned about the differences between Krovstav's graph and Gonazalez Graph and that the reseaon is due eaither to different measuring systems or due to different measured data(for example it can change when the ICL is included or excluded)
#
# * we worked step by step the math of mass halo - mass BCG
#
# * I am on Section 3 of the unix shell toturial and recording my summary on a text notebook!

# %% [markdown]
# # Wednesday: 31st of May

# %%
import random
from numpy import *
import matplotlib.pyplot as plt 
from random import randint
# %matplotlib inline
import math
from statistics import mean
from matplotlib import style
from scipy.interpolate import *

# %%
n = 30
logmHalo = np.linspace(12.0,14.0,n) 

# I need to know what will happen if I change the fraction to be a variable
fraction = 1/3.0
mGas = fraction * logmHalo

seed = 123
rand  = np.random.RandomState(seed)
variable = rand.uniform(0.0, 1.0, 30)

epsilon = logmHalo**variable

logEpsilon = np.log10(epsilon)
    
mBCG = epsilon * mGas

logMgas = math.log10(fraction) + mGas


logMBCG = []
for xx in logEpsilon:
    logMBCG.append(xx + logMgas)

# %%
fig, ax = plt.subplots()

ax.plot(logmHalo, logMBCG,'ro')
p1 = polyfit(logmHalo, logMBCG, 1)
ax.plot(logmHalo, polyval(p1,logmHalo), 'b-')

ax.set_xscale('log')
ax.set_yscale('log')

ax.set_xlabel('M_Halo (M_Solarmasses)')
ax.set_ylabel('M_BCG (M_Solarmasses)')

# %%
import random
from numpy import *
import matplotlib.pyplot as plt 
from random import randint
# %matplotlib inline
import math
from operator import add
from scipy.interpolate import *

# %%
n = 10
logmHalo = np.linspace(12.0,14.0,n) 

# I need to know what will happen if I change the fraction to be a variable
fraction = 0.1
mGas = fraction * logmHalo

seed = 123
rand  = np.random.RandomState(seed)
variable = rand.uniform(0.0, 1.0, 10)

epsilon = logmHalo**variable

logEpsilon = np.log10(epsilon)
    
mBCG = epsilon * mGas

logMgas = math.log10(fraction) + mGas


logMBCG = []
for xx in logEpsilon:
    logMBCG.append(xx + logMgas)

# %%
n = 10
logmHalo1 = np.linspace(12.0,14.0,n) 

# I need to know what will happen if I change the fraction to be a variable
fraction1 = 0.2
mGas1 = fraction1 * logmHalo1

seed = 123
rand  = np.random.RandomState(seed)
variable1 = rand.uniform(0.0, 1.0, 10)

epsilon1 = logmHalo1**variable1

logEpsilon1 = np.log10(epsilon1)
    
mBCG1 = epsilon1 * mGas1

logMgas1 = math.log10(fraction1) + mGas1


logMBCG1 = []
for xx in logEpsilon1:
    logMBCG1.append(xx + logMgas1)

# %%
n = 10
logmHalo2 = np.linspace(12.0,14.0,n) 

# I need to know what will happen if I change the fraction to be a variable
fraction2 = 0.3
mGas2 = fraction2 * logmHalo2

seed = 123
rand  = np.random.RandomState(seed)
variable2 = rand.uniform(0.0, 1.0, 10)

epsilon2 = logmHalo2**variable2

logEpsilon2 = np.log10(epsilon2)
    
mBCG2 = epsilon2 * mGas2

logMgas2 = math.log10(fraction2) + mGas2


logMBCG2 = []
for xx in logEpsilon2:
    logMBCG2.append(xx + logMgas2)

# %%
fig, ax = plt.subplots()

ax.plot(logmHalo, logMBCG,'ro')
p1 = polyfit(logmHalo, logMBCG, 1)
ax.plot(logmHalo, polyval(p1,logmHalo), 'b-')

ax.plot(logmHalo1, logMBCG1,'ro')
p2 = polyfit(logmHalo1, logMBCG1, 1)
ax.plot(logmHalo1, polyval(p2,logmHalo1), 'b-')

ax.plot(logmHalo2, logMBCG2,'ro')
p3 = polyfit(logmHalo2, logMBCG2, 1)
ax.plot(logmHalo2, polyval(p3,logmHalo2), 'b-')


ax.set_xscale('log')
ax.set_yscale('log')

ax.set_xlabel('M_Halo (M_Solarmasses)')
ax.set_ylabel('M_BCG (M_Solarmasses)')

# %%
import random
import numpy as np
import matplotlib.pyplot as plt 
from random import randint
# %matplotlib inline
import math
from operator import add
from scipy.interpolate import *

# %%
def getMstar(logMhalo, f=0.1, epsilon0=0.1, alpha=1.0, Mscale=1E14):
    logMstar = np.log10(f) + np.log10(epsilon0) - np.log10(Mscale)*alpha + (alpha + 1) * logMhalo
    return logMstar

# %%
logMhalo = np.linspace(13, 18, 50)
logMstar = getMstar(logMhalo)

# %%
# Choose a range of epsilon0 values.
epsilon0 = np.array([0.1, 0.3, 0.5, 0.7])

# %%
def efficiency_plot(logMhalo, epsilon0_grid, alpha):
    plt.rcParams.update({'font.size': 18})
    fig, ax = plt.subplots(figsize=(13, 7))
    shapes = ['--','-.','-','-o']
    for ee in range(len(epsilon0)):
        ax.plot(logMhalo,getMstar(logMhalo, epsilon0=epsilon0[ee], alpha=alpha),shapes[ee], 
                label=r'$\epsilon = {:g}$'.format(epsilon0[ee]))

    ax.text(0.8, 0.1,r'$\alpha = {:g}$'.format(alpha),bbox={'facecolor':'white', 'alpha':0.2, 'pad':10}, 
            verticalalignment='center', horizontalalignment='left',transform=ax.transAxes)
    
    ax.legend(loc='upper left')
    ax.set_xlabel(r'$\log_{10}\ (M_{halo} / M_{\odot})$')
    ax.set_ylabel(r'$\log_{10}\ (M_{*} / M_{\odot})$')
    ax.set_xlim(13, 15.5)
    ax.set_ylim(11, 14)
    #ax.set_title(r'$\alpha = {:.0f}$'.format(alpha))

# %%
efficiency_plot(logMhalo, epsilon0, alpha=-0.5)

# %%
efficiency_plot(logMhalo, epsilon0, alpha=2.0)

# %%
efficiency_plot(logMhalo, epsilon0, alpha=5.0)

# %% [markdown]
# # Thursday: 1st of June

# %% [markdown]
# we corrected the formula for our graph (it was a missing alpha).
# I need to go back and study the python language used in this graph.
# Finished the fourth section in Unix Shell tutorial and started on the fifth.As usual I recorded my notes in a text file names The Unix Shell Notes.

# %% [markdown]
# # Friday: 2nd of June

# %% [markdown]
# I continued with unix shell lessons, I am a bit stuck on the loops part... it's a bit different and I am trying to figure out what is what.
# I also started an edx course called "Introduction to Python for Data sciences" this course is an introductory course, which is designed for beginners. This course will help to master the basics of Python. I will start by doing basic arithmetic and use variables in Python. Then I will learn how to handle data structures such as Python lists, Numpy arrays and Pandas DataFrames. I will also learn about functions, packages and control flows in Python. To top it off, I will learn about visualizing your data using Python.

# %% [markdown]
# # Monday: 5th of June

# %%
import random
import numpy as np
import matplotlib.pyplot as plt 
from random import randint
# %matplotlib inline
import math
from statistics import mean
from matplotlib import style
from scipy.interpolate import *

# %%
M500_G = np.log10(np.array([2.26, 5.15, 0.95, 3.46, 3.59, 0.99, 0.95, 3.23, 2.26, 2.41, 2.37, 1.45])*1e14)
fGas_G = np.array([0.088, 0.13, 0.089, 0.126, 0.125, 0.067, 0.111, 0.133, 0.11, 0.119, 0.088, 0.075])

# %%
fig, ax = plt.subplots(figsize=(10,5))

ax.plot(M500_G, fGas_G,'ro', label="Gonzalez+  13")


ax.set_xlabel(r'$ M_{500} [ M_{\odot}]$' , fontsize = 14)
ax.set_ylabel(r'$ f_{gas} $' , fontsize = 16)


ax.set_ylim(0.01,0.2 )


coefficients = np.polyfit(M500_G, fGas_G, 1)
print(coefficients)

def getmFgas(mhalo):
    mFgas = mhalo * coefficients[0] + coefficients[1]
    
    return mFgas

getmFgas(14.3)

plt.plot(M500_G, M500_G*coefficients[0] + coefficients[1], 'b', label="Best Fit Line")
ax.legend(loc='lower right')
# Out:
# [ 0.06668714 -0.85016893]

# %%
import random
import numpy as np
import matplotlib.pyplot as plt 
from random import randint
# %matplotlib inline
import math
from operator import add
from scipy.interpolate import *

# %%
def getfgas(logMhalo):
    slop, intercept = 0.06668714, -0.85016893
    mFgas = logMhalo * 0.06668714 + (-0.85016893)
    
    return mFgas

# %%
fgas = getfgas(logMhalo)

# %%
def getMstar(logMhalo, fgas, epsilon0=0.1, alpha=1.0, Mscale=1E14):
    fgas = getfgas(logMhalo)
    logMstar = np.log10(fgas) + np.log10(epsilon0) - np.log10(Mscale)*alpha + (alpha + 1) * logMhalo
    return logMstar

# %%
logMstar = getMstar(logMhalo, fgas)

# %%
M500_K = (np.array([15.6, 10.3, 7, 5.34, 2.35, 1.86, 1.34, 0.46, 0.47])*1e14)
MBCG_K = (np.array([3.12, 4.14, 3.06, 1.47, 0.79, 1.26, 1.09, 0.91, 1.38])*1e12)

M500_G = (np.array([2.35, 5.37, 0.99, 3.6, 3.73, 1.03, 0.99, 3.37, 2.36, 2.51, 2.47, 1.51])*1e14)
LBCG_ICL_G = (np.array([0.84, 0.87, 0.33, 0.57, 0.85, 0.60, 0.86, 0.93, 0.71, 0.81, 0.7, 0.57])*2.65*1e12)

# %%
logMhalo = np.linspace(13, 18, 100)
epsilon0 = np.array([0.06,.1,.2,.3])

# %%
def efficiency_plot(logMhalo, epsilon0_grid, alpha):
    fig, ax = plt.subplots(figsize=(10,5))
    for ee in epsilon0:
        ax.plot(logMhalo, getMstar(logMhalo,fgas, epsilon0=ee, alpha=alpha), label=r'$\epsilon = {:.1f}$'.format(ee))

    ax.plot(np.log10(M500_K), np.log10(MBCG_K),'ro', label="Kravtsov+  14")
    ax.plot(np.log10(M500_G), np.log10(LBCG_ICL_G),'bs', label="Gonzalez+  13")    
    ax.legend(loc='lower right')
    ax.set_xlabel(r'$\log_{10}\ (M_{halo} / M_{\odot})$', fontsize = 12)
    ax.set_ylabel(r'$\log_{10}\ (M_{*} / M_{\odot})$', fontsize = 12)
    ax.set_xlim(13, 15.5)
    ax.set_ylim(11, 13)
    ax.set_title(r'$\alpha = {:g}$'.format(alpha))

# %%
efficiency_plot(logMhalo, epsilon0, alpha=-1)

# %% [markdown]
# # Tuesday: 6th of June

# %% [markdown]
# I have reached the 4th(Numpy) section of EdX course on python. The previous ones were:
# 1- python basics
# 2- List - A data Structure
# 3- Functions and Packages
# The next to come are:
# 4- Numpy
# 5- Plotting and Matplotlib
# 6- control flows and pandas
#
# Also below is the LogEpsilon-LogMhalo graph that you asked for.

# %%
import random
import numpy as np
import matplotlib.pyplot as plt 
from random import randint
# %matplotlib inline
import math
from operator import add
from scipy.interpolate import *

# %%
def getlogEpsilon(logMhalo, epsilon0=0.1, alpha=0.1, Mscale=1E14):
    logEpsilon = np.log10(epsilon0) + alpha * logMhalo - alpha * np.log10(Mscale)
    return 10**logEpsilon

# %%
logMhalo = np.linspace(13, 15, 20)
logEpsilon = getlogEpsilon(logMhalo)

# %%
alpha = np.array([-0.8, 0.8, 0])

# %%
def efficiency_plot(logMhalo, alpha_grid, epsilon0):
    fig, ax = plt.subplots()
    for ee in alpha:
        ax.plot(logMhalo, getlogEpsilon(logMhalo, alpha=ee, epsilon0=epsilon0), label=r'$\alpha = {:.1f}$'.format(ee))
    

    ax.legend(loc='upper left')
    ax.set_xlabel(r'$\log_{10}\ (M_{halo} / M_{\odot})$')
    ax.set_ylabel(r'$\log_{10}\ (Epsilon)$')
    #ax.set_xlim(12.5, 15.5)
    #ax.set_ylim(9.5, 15)
    ax.set_title(r'$\epsilon0 = {:.0}$'.format(epsilon0))

# %%
efficiency_plot(logMhalo, alpha, epsilon0=0.1)

# %% [markdown]
# # Wednesday: 7th of June

# %% [markdown]
# I started with the outline of the info that I would like to see on the poster. I also improved the graphs that we already did.

# %% [markdown]
# # Thursday: 9th of June + 12th of June

# %% [markdown]
# Finished with the outline and shared the google doc, waiting for approval.

# %%
import random
import numpy as np
import matplotlib.pyplot as plt 
from random import randint
# %matplotlib inline
import math
from operator import add
from scipy.interpolate import *

# %%
def getlogEpsilon(logMhalo, epsilon0=0.1, alpha=0.1, Mscale=1E14):
    logEpsilon = np.arctan(np.log10(epsilon0) + alpha * logMhalo - alpha * np.log10(Mscale))/np.pi + 1/2
    return logEpsilon

# %%
logMhalo = np.linspace(-100000, 100000, 2000000)
logEpsilon = getlogEpsilon(logMhalo)

# %%
alpha = np.array([-0.8, 0.8, 0])

# %%
def efficiency_plot(logMhalo, alpha_grid, epsilon0):
    fig, ax = plt.subplots()
    for ee in alpha:
        ax.plot(logMhalo, getlogEpsilon(logMhalo, alpha=ee, epsilon0=epsilon0), label=r'$\alpha = {:.1f}$'.format(ee))
    ax.legend(loc='upper left')
    ax.set_xlabel(r'$\log_{10}\ (M_{halo} / M_{\odot})$')
    ax.set_ylabel(r'$\log_{10}\ (Epsilon)$')
    ax.set_xlim(-8, 35)
    ax.set_ylim(-1, 2)
    #ax.set_title(r'$\epsilon0 = {:.0}$'.format(epsilon0))

# %%
efficiency_plot(logMhalo, alpha, epsilon0=6)

# %% [markdown]
# # Monday: 12th of June

# %%
import random
import numpy as np
import matplotlib.pyplot as plt 
from random import randint
# %matplotlib inline
import math
from operator import add
from scipy.interpolate import *

# %%
def getlogEpsilon(logMhalo, epsilon0=0.1, alpha=0.1, Mscale=1E14):
    logEpsilon = np.arctan(np.log10(epsilon0) + alpha * logMhalo - alpha * np.log10(Mscale))/np.pi + 1/2
    return logEpsilon

# %%
logMhalo = np.linspace(12, 15, 50)
logEpsilon = getlogEpsilon(logMhalo)

# %%
alpha = np.array([-0.1, -0.5,0.5, 1])

# %%
def efficiency_plot(logMhalo, alpha, epsilon0):
    plt.rcParams.update({'font.size': 18})
    fig, ax= plt.subplots(figsize=(13, 7))
    shapes = ['--','-.','-','-o']
    for ee in range(len(alpha)):
        ax.plot(logMhalo, getlogEpsilon(logMhalo, alpha=ee, epsilon0=epsilon0),shapes[ee], 
                label=r'$\alpha = {:g}$'.format(ee))
        
    ax.text(0.8, 0.1, r'$\epsilon_0 = {:g}$'.format(epsilon0),
            bbox={'facecolor':'white', 'alpha':0.2, 'pad':10}, verticalalignment='center', 
            horizontalalignment='left',transform=ax.transAxes)
        
    ax.legend(loc='upper left')
    ax.set_xlabel(r'$\log_{10}\ (M_{halo} / M_{\odot})$', fontsize = 24)
    ax.set_ylabel(r'Star Formation Efficiency $\epsilon$', fontsize = 24)
    ax.set_xlim(12, 15)
    ax.set_ylim(0, 1)

# %%
efficiency_plot(logMhalo, alpha, epsilon0=0.5)

# %% [markdown]
# # Tuesday and Wednesday: 13th and 14th of June

# %% [markdown]
# I worked on the taylor series expansion of our arctan equation of epsilon/Mhalo.
# Also I Tried to apply that equation to our graph(see below)

# %%
import random
import numpy as np
import matplotlib.pyplot as plt 
from random import randint
# %matplotlib inline
import math
from operator import add
from scipy.interpolate import *

# %%
def getfgas(logMhalo):
    slop, intercept = 0.06668714, -0.85016893
    mFgas = logMhalo * 0.06668714 + (-0.85016893)
    return mFgas

# %%
fgas = getfgas(logMhalo)

# %%
def getMstar(logMhalo, fgas, epsilon0=0.1, alpha=1.0, Mscale=1E14):
    fgas = getfgas(logMhalo)
    logMstar = np.arctan(np.log10(epsilon0) - np.log10(Mscale)*alpha + 
                         (alpha * logMhalo))/np.pi + np.log10(fgas) + logMhalo + 1/2
    return logMstar

# %%
logMstar = getMstar(logMhalo, fgas)

# %%
M500_K = (np.array([15.6, 10.3, 7, 5.34, 2.35, 1.86, 1.34, 0.46, 0.47])*1e14)
MBCG_K = (np.array([3.12, 4.14, 3.06, 1.47, 0.79, 1.26, 1.09, 0.91, 1.38])*1e12)

M500_G = (np.array([2.35, 5.37, 0.99, 3.6, 3.73, 1.03, 0.99, 3.37, 2.36, 2.51, 2.47, 1.51])*1e14)
LBCG_ICL_G = (np.array([0.84, 0.87, 0.33, 0.57, 0.85, 0.60, 0.86, 0.93, 0.71, 0.81, 0.7, 0.57])*2.65*1e12)

# %%
logMhalo = np.linspace(13, 18, 100)
epsilon0 = np.array([0.01, 0.1, 0.9])

# %%
def efficiency_plot(logMhalo, epsilon0, alpha):
    fig, ax = plt.subplots(figsize=(10,5))
    for ee in epsilon0:
        ax.plot(logMhalo, getMstar(logMhalo,fgas, epsilon0=ee, alpha=alpha), label=r'$\epsilon = {:.1f}$'.format(ee))

    ax.plot(np.log10(M500_K), np.log10(MBCG_K),'ro', label="Kravtsov+  14")
    ax.plot(np.log10(M500_G), np.log10(LBCG_ICL_G),'bs', label="Gonzalez+  13")    
    ax.legend(loc='lower right')
    ax.set_xlabel(r'$\log_{10}\ (M_{halo} / M_{\odot})$', fontsize = 18)
    ax.set_ylabel(r'$\log_{10}\ (M_{*} / M_{\odot})$', fontsize = 18)
    ax.set_xlim(13, 17)
    ax.set_ylim(10, 18)
    ax.set_title(r'$\alpha = {:g}$'.format(alpha))

# %%
 efficiency_plot(logMhalo, epsilon0, alpha=1)

# %% [markdown]
# # Thursday: 15th of June

# %% [markdown]
# I read all the needed info from Physical Models of Galaxy Formation in a Cosmological FrameWork, that wwill be used in our poster. Also I worked on our simple model graph, by making the epsinlon a constant and alpha a variable(see below)

# %%
import random
import numpy as np
import matplotlib.pyplot as plt 
from random import randint
# %matplotlib inline
import math
from operator import add
from scipy.interpolate import *

# %%
def getMstar(logMhalo, f=0.1, epsilon0=0.1, alpha=1.0, Mscale=1E14):
    logMstar = np.log10(f) + np.log10(epsilon0) - np.log10(Mscale)*alpha + (alpha + 1) * logMhalo
    return logMstar

# %%
logMhalo = np.linspace(13, 18, 50)
logMstar = getMstar(logMhalo)

# %%
# Choose a range of epsilon0 values.
alpha = np.array([-1, -0.5,0.5, 1])

# %%
def efficiency_plot(logMhalo, alpha, epsilon0):
    plt.rcParams.update({'font.size': 18})
    fig, ax= plt.subplots(figsize=(13, 7))
    shapes = ['--','-.','-','-o']
    for ee in range(len(alpha)):
        ax.plot(logMhalo,getMstar(logMhalo, epsilon0=epsilon0, alpha=(ee)), shapes[ee], 
                label=r'$\alpha = {:g}$'.format(ee))
    
    ax.text(0.8, 0.1, r'$\epsilon_0 = {:g}$'.format(epsilon0),
               bbox={'facecolor':'white', 'alpha':0.2, 'pad':10}, verticalalignment='center', 
               horizontalalignment='left',transform=ax.transAxes)
    
    ax.legend(loc= 'upper left')
    ax.set_xlabel(r'$\log_{10}\ (M_{halo} / M_{\odot})$', fontsize = 24)
    ax.set_ylabel(r'$\log_{10}\ (M_{*} / M_{\odot})$', fontsize = 24)
    ax.set_xlim(13, 15.5)
    ax.set_ylim(11, 14)
    #ax.set_title(r'$\epsilon0 = {:0g}$'.format(epsilon0))

# %%
efficiency_plot(logMhalo, alpha, epsilon0= 0.1)

# %% [markdown]
# # Friday, Monday:16th , 19th of June

# %% [markdown]
# We were working on the poster

# %% [markdown]
# # Tuesday: 20th of June

# %% [markdown]
# Completed the Poster and working again on the Edx python Course Section(Numpy) and recording any comments
