# %%
import time
import random
import numpy as np
import matplotlib.pylab as plt
t0= time.time()
a=np.array([random.random() for _ in xrange(100000000)])
hist=plt.hist(a,bins=100)
tot_freq=hist[0]
print tot_freq
t1=time.time()
tot=t1-t0
print 'This code took %f seconds to run' %tot
# Out:
# [  998806.   998773.   999663.   998915.  1000522.   998119.  1000207.
#   1002582.   998718.  1001239.   997895.   999572.   999498.  1001284.
#    997190.   998875.  1001662.  1000793.   998644.   998629.  1000402.
#    999731.   999659.   999511.   999132.  1001977.   999910.   999775.
#   1000210.  1000993.  1000321.  1000428.  1000378.   999174.  1001026.
#   1000708.   999365.  1001218.  1001737.   998900.   998847.  1001747.
#   1000086.  1000361.   999439.   999053.   999707.  1000271.  1000825.
#   1001524.   999698.   999643.  1000847.  1001138.  1001121.  1000201.
#    999958.  1001625.   999982.   999478.  1000119.   999223.   999142.
#   1001426.  1000846.   998947.  1001174.   997314.  1000763.   998421.
#    999688.   999420.   999774.  1000099.  1000303.   999922.   999377.
#   1001106.  1001421.  1000832.   998417.   999567.  1000786.  1001282.
#    999799.  1000531.   999392.   999374.  1001556.   999616.   999415.
#   1000389.   998990.   999624.  1001616.   999039.   999904.   999632.
#   1000342.   999720.]
# This code took 19.911451 seconds to run

# %%
import time
import random
import numpy as np
import matplotlib.pylab as plt
t0=time.time()
tot_freq=np.zeros(100)
for i in range(0,100):
    a=np.array([random.random() for _ in xrange(1000000)])
    hist=plt.hist(a,bins=100)
    tot_freq+=hist[0]
    del a
    del hist
print tot_freq
t1=time.time()
tot=t1-t0
print 'This code took %f seconds to run' %tot
# Out:
# [  999449.   998836.  1000737.   997753.  1000751.  1000799.   999525.
#   1000964.   997886.  1001343.   998562.   998461.   999295.  1000215.
#    998973.   999641.   998383.   999078.   998642.   999004.  1000420.
#   1001116.   999924.   999888.  1000623.  1000883.   999493.  1000130.
#    999537.  1000493.   998880.  1000448.   997651.   999402.   997529.
#    999646.   999708.  1000230.  1000924.   998359.  1000352.  1000386.
#   1000565.   999955.   998695.  1000594.  1000980.  1000138.   999189.
#   1001396.  1000333.  1000578.  1000891.   999246.  1000287.   999228.
#    999805.  1001252.  1000480.  1000909.  1001775.   998564.  1000751.
#    999379.  1000625.  1000107.  1001453.  1001001.  1000572.  1000017.
#   1001638.  1000557.  1000350.   999985.   999722.   999225.  1001034.
#   1001122.  1000187.   999612.  1000392.  1000879.   999259.  1000010.
#    998436.  1000278.  1000482.   999270.  1001030.  1000553.   999168.
#    999613.  1000559.   999860.  1001971.  1000253.  1000064.  1000352.
#   1000772.  1000283.]
# This code took 28.459699 seconds to run
